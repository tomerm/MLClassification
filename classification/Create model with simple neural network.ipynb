# %% [markdown]
# #### Declarations and definitions

# %%
import numpy
import gensim
from gensim.models.word2vec import Word2Vec
from keras.preprocessing import sequence
from gensim.models.doc2vec import TaggedDocument
from collections import namedtuple
from keras.models import load_model
import statistics
import random
import glob
import os
import datetime
from pathlib import Path
import matplotlib.pyplot as plt

homePath = str(Path.home()) + "/MLClassificationData"
LabeledSentence = gensim.models.doc2vec.TaggedDocument
# Dimension of word vectors
n_dim = 100
# Count of categories (labels).
n_cats = 0
# Count of words, which aren't found in w2v vocabulary.
nf_words = 0
# This id is included into the names of models, created by this notebook.
modelId = 1
# Path to tokenized corpus for training
trainRoot = homePath + '/train/rtanews/target'
# Path to tokenized corpus for testing
testRoot = homePath + '/test/rtanews/target'
# Path for saving best results, achieved in the time of training
best_models_path = homePath + '/models/rtanews/tempModels/'
# Part of the training corpus, used for runtime validation
valPart = 0.15
batch_size = 128
numpy.random.seed(1)
cnt = 0
nCats = 0
categories = dict()

LabeledDocument = namedtuple('LabeledDocument', 'words labels qLabs')

def getCategories(path):
    cats = dict()
    nCats = 0
    os.chdir(path)
    for f in glob.glob("*"):
        if os.path.isdir(f):
            cats[f] = nCats
            nCats += 1
    return cats

def prepareDocsData(path, cats):
    files = dict()
    fInCats = [0] * len(cats)
    nFiles = 0
    actFiles = 0
    curCategory = 0
    docs = []
    os.chdir(path)
    rootDir = os.getcwd()
    for f in glob.glob("*"):
        curCategory = cats[f]
        catPath = path + "/" + f
        os.chdir(catPath)
        for fc in glob.glob("*"):
            actFiles += 1
            if fc not in files:
                nFiles += 1
                fPath = catPath + "/" + fc
                docCont = ''
                with open(fc, 'r', encoding='UTF-8') as tc:
                    for line in tc:
                        docCont += line.strip() + " "
                tc.close()
                words = docCont.strip().split() 
                labels = [0] * len(cats)
                labels[curCategory] = 1
                files[fc] = LabeledDocument(words, labels, [1])
            else:
                files[fc].labels[curCategory] = 1
                files[fc].qLabs[0] += 1
            fInCats[curCategory] += 1
    for k, val in files.items():
        docs.append(val)
    return docs, fInCats

def getLabelSets(docs):
    labels = [x[1] for x in docs]
    results = [labels[0]]
    qLabs = 0
    for i in range(len(labels)):        
        if i%1000 == 0:
            print (str(i), end='\r')
        qLabs += sum(labels[i])
        count = 0
        for j in range(len(results)):
            for k in range(len(categories)):
                if labels[i][k] != results[j][k]:
                    count += 1
                    break
        if count == len(results):
            results.append(labels[i])
    return len(results), qLabs
    
def showTime(ds,de):
    result = ''
    seconds = (de-ds).total_seconds()
    if seconds < 1:
        return "less than 1 sec"
    hh = int(seconds/(60*60));
    if hh > 0:
        result = "%d h:"%(hh);
    seconds -= hh*60*60
    mm = int(seconds/60);
    if mm > 0:
        result += "%d min:"%(mm)
    ss = seconds - mm*60;
    result += "%d sec"%(ss)
    return result

def showDocsByLength(plt):
    fig, (plot1, plot2) = plt.subplots(1, 2, figsize=(10,6))    
    dictLens = dict()
    dictLens1 = dict()
    for i in range(len(trainDocs)):
        lend = "%5d"%(len(trainDocs[i].words))
        if not lend in dictLens:
            dictLens[lend] = 1
        else:
            dictLens[lend] += 1
    lens = sorted(list(dictLens.items()))
    lvars = [int(x[0]) for x in lens]
    locc = [x[1] for x in lens]
    plot1.set_title ("Documents by tokens in training set")
    plot1.set_ylabel("Documents")
    plot1.set_xlabel("Tokens")
    plot1.plot(lvars, locc, "b.-") 
    for i in range(len(testDocs)):
        lend = "%5d"%(len(testDocs[i].words))
        if not lend in dictLens1:
            dictLens1[lend] = 1
        else:
            dictLens1[lend] += 1
    lens1 = sorted(list(dictLens1.items()))
    lvars1 = [int(x[0]) for x in lens1]
    locc1 = [x[1] for x in lens1]
    plot2.set_title ("Documents by tokens in testing set")
    #plot2.set_ylabel("Documents")
    plot2.set_xlabel("Tokens")
    plot2.yaxis.tick_right()
    plot2.plot(lvars1, locc1, "b.-") 
    plt.show()
    
def showDocsByLabs(plt):
    fig, (plot1, plot2) = plt.subplots(1, 2, figsize=(10,6))
    dictLabs = dict()
    dictLabs1 = dict()
    for i in range(len(trainDocs)):
        lab = "%5d"%(trainDocs[i].qLabs[0])
        if not lab in dictLabs:
            dictLabs[lab] = 1
        else:
            dictLabs[lab] += 1
    labs = sorted(list(dictLabs.items()))
    lvars1 = [int(x[0]) for x in labs]
    locc1 = [x[1] for x in labs]
    plot1.set_title ("Documents by labels in training set")
    plot1.set_ylabel("Documents")
    plot1.set_xlabel("Labels")
    plot1.set_xticks(numpy.arange(0, len(categories), step=1))
    plot1.plot(lvars1, locc1, "bo-")
    for i in range(len(testDocs)):
        lab = "%5d"%(testDocs[i].qLabs[0])
        if not lab in dictLabs1:
            dictLabs1[lab] = 1
        else:
            dictLabs1[lab] += 1
    labs1 = sorted(list(dictLabs1.items()))
    lvars2 = [int(x[0]) for x in labs1]
    locc2 = [x[1] for x in labs1]
    plot2.set_title ("Documents by labels in testing set")
    #plot2.set_ylabel("Documents")
    plot2.set_xlabel("Labels")
    plot2.set_xticks(numpy.arange(0, len(categories), step=1))
    plot2.yaxis.tick_right()
    plot2.plot(lvars2, locc2, "bo-")
    plt.show()

# %% [markdown]
# #### Loading input datasets
# Load documents from the files, placed under given root folders (for training and testing separately).
# Files wich belong to some specific category are placed into the same subfolder of the root.
# Name of such subfolder is treated as a name of category.
# File which belongs to few categories should be copied into all correspondig subfolders (but will be loaded only once).

# %%
ds = datetime.datetime.now()
categories = getCategories(trainRoot)
#print (categories)
trainAllDocs, fInCats1 = prepareDocsData(trainRoot, categories)
trainAllDocs = random.sample(trainAllDocs, len(trainAllDocs))
trainDocs = trainAllDocs[:int(len(trainAllDocs) * (1 - valPart))]
valDocs = trainAllDocs[int(len(trainAllDocs) * (1 - valPart)):]
testDocs, fInCats2 = prepareDocsData(testRoot, categories)
testDocs = random.sample(testDocs, len(testDocs))
de = datetime.datetime.now()

print ("Load input data in %s"%(showTime(ds, de)))
# Out:
# Load input data in 4 sec

# %% [markdown]
# #### Dataset analysis

# %%
print ("Dataset properties:")
maxDocLen = max(len(x.words) for x in trainAllDocs)
minDocLen = min(len(x.words) for x in trainAllDocs)
avrgDocLen = round(statistics.mean(len(x.words) for x in trainAllDocs), 2)
dls, qLabs = getLabelSets(trainAllDocs)

print ('Loaded %d documents: %d for training, %d for validation, %d for test' % (len(trainAllDocs) + len(testDocs), len(trainDocs), len(valDocs), len(testDocs)))
print ("Tokens in documents: maximum: %d, minimum: %d, average: %d"%(maxDocLen, minDocLen, avrgDocLen))
showDocsByLength(plt);
print ("Categories (labels): %d"%(len(categories)))
print ("Documents for training in category : maximum: %d, minimum: %d, avegare: %d"%(max(fInCats1), min(fInCats1), round(statistics.mean(fInCats1), 2)))
print ("Documents for testing  in category : maximum: %d, minimum: %d, avegare: %d"%(max(fInCats2), min(fInCats2), round(statistics.mean(fInCats2), 2)))
showDocsByLabs(plt)
print ("Distinct Label Set: %d"%(dls))
print ("Proportion of Distinct Label Set: %.4f"%(dls/len(trainAllDocs)))
print ("Label Cardinality: %.4f"%(qLabs/len(trainAllDocs)))
print ("Label Density: %.4f"%(qLabs/len(trainAllDocs)/len(categories)))

del trainAllDocs
# Out:
# Dataset properties:
# Loaded 23837 documents: 12750 for training, 2251 for validation, 8836 for test
# Tokens in documents: maximum: 1330, minimum: 46, average: 170
# Categories (labels): 40
# Documents for training in category : maximum: 2800, minimum: 93, avegare: 415
# Documents for testing  in category : maximum: 1501, minimum: 65, avegare: 276
# Distinct Label Set: 290
# Proportion of Distinct Label Set: 0.0193
# Label Cardinality: 1.1073
# Label Density: 0.0277

# %% [markdown]
# #### Load W2V model
# Load Word2Vec model, saved previously in a text format.

# %%
# Name of file with word vectors
modelName = 'model-2018-Nov-12-011941.vec'
#modelName = 'wiki_ar.vec'
ds = datetime.datetime.now()
w2v = gensim.models.KeyedVectors.load_word2vec_format(homePath + '/w2v/vectors/' + modelName)
de = datetime.datetime.now()
print ("Load W2V model (%s) in %s"%(modelName, showTime(ds, de))) 
print ("Continue")
# Out:
# Load W2V model (model-2018-Nov-12-011941.vec) in 1 min:49 sec
# Continue

# %% [markdown]
# #### Prepare data for training and testing
# Input data is converted into array of sequences so that documents of different length are represented by sequences of numbers of the same size.

# %%
nf_words = 0
sdict = dict()
nfw = []
def getDocsArray(tokens, wvModel, dataType):
    global n_dim
    global tmpCount
    global nf_words
    global sdict
    global nfw
    tmpCount = tmpCount + 1
    if tmpCount != 0 and tmpCount%1000 == 0:
        print(dataType + ": prepare ", tmpCount, end="\r")
        
    vec = numpy.zeros(n_dim).reshape((1, n_dim))
    count = 0.
    for word in tokens:
        if word not in sdict:
            sdict[word] = 1
        else:
            sdict[word] = sdict[word] + 1
    for word in tokens:
        try:
            vec += wvModel[word].reshape((1, n_dim)) 
            count += 1.
        except KeyError:
            if sdict[word] == 1:
                nf_words += 1
                if nf_words < 10:
                    nfw.append(word)
            continue
    if count != 0:
        vec /= count
    return vec
    
ds = datetime.datetime.now()
tmpCount = 0
train_arrays = numpy.concatenate([getDocsArray(x.words, w2v, 'Train') for x in trainDocs])
tmpCount = 0
val_arrays = numpy.concatenate([getDocsArray(x.words, w2v, 'Validation') for x in valDocs])
train_labels = numpy.concatenate([numpy.array(x.labels).reshape(1, len(categories)) for x in trainDocs])
val_labels = numpy.concatenate([numpy.array(x.labels).reshape(1, len(categories)) for x in valDocs])
tmpCount = 0
de = datetime.datetime.now()
print ("Prepare train and validation data in %s"%(showTime(ds, de)))

ds = datetime.datetime.now()
test_arrays = numpy.concatenate([getDocsArray(x.words, w2v, "Test") for x in testDocs])
test_labels = numpy.concatenate([numpy.array(x.labels).reshape(1, len(categories)) for x in testDocs])
de = datetime.datetime.now()
print ("Prepare test data in %s"%(showTime(ds, de)))
print ("Unique words in all documents: %d"%(len(sdict)))
print ("Words not found in the w2v vocabulary: %d"%(nf_words))
# Out:
# Prepare train and validation data in 46 sec
# Prepare test data in 28 sec
# Unique words in all documents: 155089
# Words not found in the w2v vocabulary: 34347

# %% [markdown]
# #### Create, train and test the model
# Classification model is created here as an linear stack of few regular densely-connected neural network's layers.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.callbacks import ModelCheckpoint
from keras import optimizers
from keras.metrics import categorical_accuracy
import math

def getModel(n_dim):
    global batch_size
    model = Sequential()
    model.add(Dense(256, activation='relu', input_dim=n_dim))
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(len(categories), activation='sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    return model    

model = getModel(n_dim)
# Quantity of epochs (loops) in which model is trained
eps = 30
verbose = 0
checkpoint = ModelCheckpoint(best_models_path + 'curModel%d.hdf5'%(modelId), monitor='val_acc', verbose=verbose, save_best_only=True, mode='auto')
print("Start training...", end='\r')

ds = datetime.datetime.now()
model.fit(train_arrays, train_labels, epochs=eps, validation_data=(val_arrays, val_labels), batch_size=batch_size, verbose=0, callbacks=[checkpoint], shuffle=False)
de = datetime.datetime.now()
print ("Model trained in %s"%(showTime(ds, de)))

# Evaluation of the final model
scores = model.evaluate(test_arrays, test_labels, verbose=1)
print("Final model accuracy: %.2f%%" % (scores[1]*100))

# Evaluation of the best model, saved in the training time
model1 = load_model(best_models_path + 'curModel%d.hdf5'%(modelId))
scores = model1.evaluate(test_arrays, test_labels, verbose=1)
print("Last saved model accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Model trained in 44 sec
# 8836/8836 [==============================] - 1s 80us/step
# Final model accuracy: 98.49%
# 8836/8836 [==============================] - 1s 104us/step
# Last saved model accuracy: 98.50%

# %% [markdown]
# #### Save the model

# %%
# Set 'False' if you want to use the best model, saved in the training time
useFinalModel = True

modelPath = homePath + "/models/rtanews/models/"
modelName = "model%d-%s"%(modelId, datetime.datetime.now().strftime("%Y-%b-%d-%H%M%S"))

ds = datetime.datetime.now() 
if not useFinalModel:
    del model
    model = model1    
model.save(modelPath + modelName)
os.remove(best_models_path + 'curModel%d.hdf5'%(modelId))
de = datetime.datetime.now()
print ("Model %s saved in %s"%(modelName, showTime(ds,de)))
# Out:
# Model model1-2018-Nov-16-000110 saved in less than 1 sec

# %% [markdown]
# #### Check results visually

# %%
cNames = [''] * len(categories)
step = 100

def getPrediction(entry):
    return entry[1]

for k,v in categories.items():
    cNames[v] = k
for id in range(0, len(test_arrays)-1, step):
    if id > 0:
        print()
    taggedFor = "Tagged for: "
    cTags = 0
    for i in range(len(categories)):
        if test_labels[id][i] == 1:
            if cTags != 0:
                taggedFor += " , "
            cTags += 1        
            taggedFor += cNames[i]        
    res = model.predict(test_arrays[id].reshape(1, n_dim))
    list = [(0,0) for i in range(len(categories))]
    for i in range(len(categories)):
        list[i] = (i, res[0][i])
    list.sort(key=getPrediction, reverse=True)
    print ("Document %d %s"%(id+1, taggedFor))
    print ("Predictions (with probability of more than one percent):")
    for i in range(len(categories)):
        if list[i][1] >= 0.01:
            print ("\t%35s  %.2f%%" % (cNames[list[i][0]], list[i][1] * 100))
# Out:
# Document 1 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	         28.Operation_Freeing_Mosul  41.35%
# 	          07.Crisis_Syrian conflict  23.76%
# 	                    22.Groups_armed  16.58%
# 	      15.Opposition_Syrian conflict  3.67%
# 	  03.Weapons_and_military_equipment  2.77%
# 	          13.Technology_Information  1.06%
# 	                     05.Discoveries  1.06%
#
# Document 101 Tagged for: 31.Catastrophes_Air
# Predictions (with probability of more than one percent):
# 	                31.Catastrophes_Air  99.12%
# 	                   25.Army_Aircraft  2.87%
#
# Document 201 Tagged for: 29.Space
# Predictions (with probability of more than one percent):
# 	                           29.Space  99.94%
#
# Document 301 Tagged for: 15.Opposition_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  88.59%
# 	      15.Opposition_Syrian conflict  41.55%
# 	                    22.Groups_armed  4.63%
# 	               26.Economy_Sanctions  1.39%
#
# Document 401 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  100.00%
#
# Document 501 Tagged for: 23.Sports_Other
# Predictions (with probability of more than one percent):
# 	      19.Olympics_Ryu_d_Janero_2016  92.03%
# 	                    23.Sports_Other  39.34%
#
# Document 601 Tagged for: 11.Research_Medical
# Predictions (with probability of more than one percent):
# 	                        17.Diseases  82.87%
# 	                11.Research_Medical  28.63%
# 	                     05.Discoveries  4.30%
# 	             36.General_information  3.74%
#
# Document 701 Tagged for: 07.Crisis_Syrian conflict , 15.Opposition_Syrian conflict , 22.Groups_armed
# Predictions (with probability of more than one percent):
# 	      15.Opposition_Syrian conflict  74.17%
# 	          07.Crisis_Syrian conflict  43.17%
# 	                    22.Groups_armed  27.71%
# 	                   25.Army_Aircraft  4.42%
#
# Document 801 Tagged for: 22.Groups_armed , 03.Weapons_and_military_equipment
# Predictions (with probability of more than one percent):
# 	         28.Operation_Freeing_Mosul  47.75%
# 	                        32.Refugees  46.25%
# 	          07.Crisis_Syrian conflict  28.87%
# 	                    22.Groups_armed  16.06%
# 	      15.Opposition_Syrian conflict  1.75%
#
# Document 901 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  99.99%
#
# Document 1001 Tagged for: 20.Explosions , 21.Crimes , 22.Groups_armed
# Predictions (with probability of more than one percent):
# 	                    22.Groups_armed  85.94%
# 	                          21.Crimes  69.96%
# 	                      20.Explosions  1.78%
#
# Document 1101 Tagged for: 23.Sports_Other
# Predictions (with probability of more than one percent):
# 	                    23.Sports_Other  99.99%
#
# Document 1201 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  99.99%
#
# Document 1301 Tagged for: 23.Sports_Other
# Predictions (with probability of more than one percent):
# 	                    23.Sports_Other  99.90%
#
# Document 1401 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  100.00%
#
# Document 1501 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  99.95%
#
# Document 1601 Tagged for: 32.Refugees
# Predictions (with probability of more than one percent):
# 	                        32.Refugees  65.50%
# 	                   14.Tourism_World  8.09%
# 	                16.Migration_Europe  2.94%
# 	                  35.Demonstrations  1.34%
# 	     09.Recognition_State_Palestine  1.30%
#
# Document 1701 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  100.00%
#
# Document 1801 Tagged for: 05.Discoveries , 03.Weapons_and_military_equipment , 36.General_information
# Predictions (with probability of more than one percent):
# 	                     05.Discoveries  46.40%
# 	          13.Technology_Information  44.32%
# 	  03.Weapons_and_military_equipment  13.10%
# 	             36.General_information  8.16%
# 	                11.Research_Medical  5.65%
# 	                          21.Crimes  3.58%
# 	                           33.Drugs  2.62%
# 	                    22.Groups_armed  1.67%
# 	                        17.Diseases  1.18%
#
# Document 1901 Tagged for: 20.Explosions , 21.Crimes , 32.Refugees
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  44.49%
# 	                    22.Groups_armed  43.15%
# 	                      20.Explosions  28.64%
# 	      15.Opposition_Syrian conflict  9.43%
# 	         28.Operation_Freeing_Mosul  8.31%
# 	                          21.Crimes  5.66%
# 	                        32.Refugees  3.66%
# 	                   25.Army_Aircraft  1.47%
# 	                    40.Attacs_Paris  1.46%
#
# Document 2001 Tagged for: 22.Groups_armed
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  77.56%
# 	                    22.Groups_armed  56.85%
# 	      15.Opposition_Syrian conflict  21.58%
#
# Document 2101 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  62.86%
# 	                    22.Groups_armed  47.91%
# 	      15.Opposition_Syrian conflict  17.35%
# 	                     04.Oil_markets  4.50%
# 	  01.Agreement_Iran_Nuclear_weapons  1.72%
# 	  03.Weapons_and_military_equipment  1.30%
#
# Document 2201 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  98.68%
# 	                    23.Sports_Other  5.76%
#
# Document 2301 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  100.00%
#
# Document 2401 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  55.93%
# 	  01.Agreement_Iran_Nuclear_weapons  35.54%
# 	                    22.Groups_armed  12.27%
# 	      15.Opposition_Syrian conflict  10.38%
# 	               26.Economy_Sanctions  7.82%
# 	                  08.Crisis_Yemenis  2.29%
# 	                         24.Rockets  2.19%
#
# Document 2501 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  99.93%
#
# Document 2601 Tagged for: 07.Crisis_Syrian conflict , 32.Refugees
# Predictions (with probability of more than one percent):
# 	                        32.Refugees  98.29%
# 	          07.Crisis_Syrian conflict  34.92%
# 	                16.Migration_Europe  10.53%
# 	                          34.Famous  1.19%
#
# Document 2701 Tagged for: 09.Recognition_State_Palestine
# Predictions (with probability of more than one percent):
# 	     09.Recognition_State_Palestine  74.05%
# 	          07.Crisis_Syrian conflict  17.40%
# 	                    22.Groups_armed  4.32%
# 	                  08.Crisis_Yemenis  2.20%
#
# Document 2801 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  100.00%
#
# Document 2901 Tagged for: 17.Diseases
# Predictions (with probability of more than one percent):
# 	                         24.Rockets  72.50%
# 	                        17.Diseases  5.21%
# 	                     05.Discoveries  4.45%
# 	                    22.Groups_armed  3.49%
# 	                      20.Explosions  2.38%
# 	                          21.Crimes  1.92%
#
# Document 3001 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  83.87%
# 	      15.Opposition_Syrian conflict  17.04%
# 	                   25.Army_Aircraft  12.16%
# 	                         24.Rockets  9.82%
# 	                    22.Groups_armed  5.00%
# 	  03.Weapons_and_military_equipment  2.95%
#
# Document 3101 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  92.76%
# 	      15.Opposition_Syrian conflict  18.97%
# 	                    22.Groups_armed  3.13%
#
# Document 3201 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  99.51%
#
# Document 3301 Tagged for: 02.Referendum_Britain
# Predictions (with probability of more than one percent):
# 	              02.Referendum_Britain  99.99%
#
# Document 3401 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  99.74%
# 	                    23.Sports_Other  1.25%
#
# Document 3501 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  99.92%
#
# Document 3601 Tagged for: 25.Army_Aircraft
# Predictions (with probability of more than one percent):
# 	                   25.Army_Aircraft  63.86%
# 	  03.Weapons_and_military_equipment  29.52%
# 	      19.Olympics_Ryu_d_Janero_2016  19.33%
# 	              37.Military_Maneuvers  6.53%
# 	                    23.Sports_Other  6.31%
# 	                         24.Rockets  6.01%
# 	                31.Catastrophes_Air  3.54%
#
# Document 3701 Tagged for: 06.Crisis_Ukrainian , 10.Election_America
# Predictions (with probability of more than one percent):
# 	                06.Crisis_Ukrainian  98.65%
# 	                10.Election_America  13.10%
#
# Document 3801 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  100.00%
#
# Document 3901 Tagged for: 06.Crisis_Ukrainian
# Predictions (with probability of more than one percent):
# 	                06.Crisis_Ukrainian  99.64%
#
# Document 4001 Tagged for: 15.Opposition_Syrian conflict , 22.Groups_armed
# Predictions (with probability of more than one percent):
# 	                    22.Groups_armed  79.56%
# 	                      20.Explosions  20.68%
# 	          07.Crisis_Syrian conflict  3.74%
# 	      15.Opposition_Syrian conflict  2.48%
# 	                    40.Attacs_Paris  1.65%
#
# Document 4101 Tagged for: 22.Groups_armed
# Predictions (with probability of more than one percent):
# 	                    22.Groups_armed  95.87%
# 	                          21.Crimes  2.04%
#
# Document 4201 Tagged for: 22.Groups_armed
# Predictions (with probability of more than one percent):
# 	                    22.Groups_armed  54.33%
# 	         28.Operation_Freeing_Mosul  11.72%
# 	                    40.Attacs_Paris  9.34%
# 	                      20.Explosions  6.15%
# 	          07.Crisis_Syrian conflict  5.28%
# 	      15.Opposition_Syrian conflict  4.75%
# 	                   25.Army_Aircraft  3.28%
# 	                         24.Rockets  1.88%
#
# Document 4301 Tagged for: 39.Economy_Indicators
# Predictions (with probability of more than one percent):
# 	              39.Economy_Indicators  99.06%
# 	                     04.Oil_markets  13.72%
# 	  03.Weapons_and_military_equipment  6.99%
#
# Document 4401 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  100.00%
#
# Document 4501 Tagged for: 07.Crisis_Syrian conflict , 15.Opposition_Syrian conflict
# Predictions (with probability of more than one percent):
# 	      15.Opposition_Syrian conflict  95.30%
# 	          07.Crisis_Syrian conflict  52.86%
# 	                    22.Groups_armed  9.82%
#
# Document 4601 Tagged for: 11.Research_Medical , 17.Diseases
# Predictions (with probability of more than one percent):
# 	                        17.Diseases  70.89%
# 	                11.Research_Medical  38.23%
# 	             36.General_information  31.55%
#
# Document 4701 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  92.10%
# 	                    22.Groups_armed  11.00%
# 	                  08.Crisis_Yemenis  8.18%
# 	                        32.Refugees  1.27%
#
# Document 4801 Tagged for: 22.Groups_armed
# Predictions (with probability of more than one percent):
# 	                          21.Crimes  91.27%
# 	                    22.Groups_armed  13.36%
# 	                      20.Explosions  2.43%
# 	                  35.Demonstrations  1.76%
# 	                        32.Refugees  1.31%
#
# Document 4901 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  95.57%
# 	                10.Election_America  29.63%
# 	                06.Crisis_Ukrainian  2.81%
# 	                    22.Groups_armed  1.22%
#
# Document 5001 Tagged for: 23.Sports_Other
# Predictions (with probability of more than one percent):
# 	                    23.Sports_Other  99.79%
#
# Document 5101 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  77.89%
# 	                     04.Oil_markets  64.78%
# 	              39.Economy_Indicators  11.98%
# 	               26.Economy_Sanctions  7.72%
# 	                06.Crisis_Ukrainian  6.25%
# 	                    22.Groups_armed  1.31%
# 	  01.Agreement_Iran_Nuclear_weapons  1.15%
#
# Document 5201 Tagged for: 25.Army_Aircraft , 03.Weapons_and_military_equipment
# Predictions (with probability of more than one percent):
# 	                   25.Army_Aircraft  98.64%
# 	  03.Weapons_and_military_equipment  1.51%
#
# Document 5301 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  80.26%
# 	                    22.Groups_armed  7.55%
# 	      15.Opposition_Syrian conflict  5.59%
# 	                         24.Rockets  4.78%
# 	  03.Weapons_and_military_equipment  4.52%
# 	                   25.Army_Aircraft  2.99%
#
# Document 5401 Tagged for: 35.Demonstrations
# Predictions (with probability of more than one percent):
# 	                  35.Demonstrations  86.38%
# 	                     04.Oil_markets  29.84%
# 	                    22.Groups_armed  21.14%
# 	                06.Crisis_Ukrainian  2.15%
# 	                          21.Crimes  1.57%
#
# Document 5501 Tagged for: 06.Crisis_Ukrainian
# Predictions (with probability of more than one percent):
# 	                    22.Groups_armed  60.05%
# 	                06.Crisis_Ukrainian  16.30%
# 	                          21.Crimes  9.14%
# 	          07.Crisis_Syrian conflict  2.79%
#
# Document 5601 Tagged for: 22.Groups_armed
# Predictions (with probability of more than one percent):
# 	                    22.Groups_armed  72.20%
# 	                     18.Coup_Turkey  28.10%
#
# Document 5701 Tagged for: 31.Catastrophes_Air
# Predictions (with probability of more than one percent):
# 	                31.Catastrophes_Air  64.92%
# 	                      20.Explosions  19.92%
# 	                          21.Crimes  4.18%
# 	                    22.Groups_armed  3.51%
# 	                        30.Football  3.28%
# 	                    40.Attacs_Paris  2.60%
# 	                        32.Refugees  2.22%
# 	                   14.Tourism_World  2.21%
# 	          07.Crisis_Syrian conflict  2.10%
# 	                        17.Diseases  1.67%
#
# Document 5801 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  99.95%
#
# Document 5901 Tagged for: 37.Military_Maneuvers , 03.Weapons_and_military_equipment
# Predictions (with probability of more than one percent):
# 	                         24.Rockets  56.36%
# 	  03.Weapons_and_military_equipment  36.72%
# 	              37.Military_Maneuvers  20.63%
# 	          13.Technology_Information  5.23%
#
# Document 6001 Tagged for: 08.Crisis_Yemenis
# Predictions (with probability of more than one percent):
# 	                  08.Crisis_Yemenis  99.51%
# 	                         24.Rockets  1.67%
# 	                    22.Groups_armed  1.15%
#
# Document 6101 Tagged for: 08.Crisis_Yemenis
# Predictions (with probability of more than one percent):
# 	                  08.Crisis_Yemenis  99.95%
#
# Document 6201 Tagged for: 04.Oil_markets
# Predictions (with probability of more than one percent):
# 	                     04.Oil_markets  100.00%
#
# Document 6301 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  100.00%
#
# Document 6401 Tagged for: 29.Space
# Predictions (with probability of more than one percent):
# 	                           29.Space  98.92%
#
# Document 6501 Tagged for: 19.Olympics_Ryu_d_Janero_2016 , 23.Sports_Other
# Predictions (with probability of more than one percent):
# 	                    23.Sports_Other  96.86%
# 	      19.Olympics_Ryu_d_Janero_2016  21.94%
#
# Document 6601 Tagged for: 30.Football , 35.Demonstrations
# Predictions (with probability of more than one percent):
# 	                    40.Attacs_Paris  64.58%
# 	                    22.Groups_armed  17.99%
# 	                        32.Refugees  11.06%
# 	                   14.Tourism_World  9.68%
# 	                  35.Demonstrations  9.13%
# 	                          21.Crimes  6.21%
# 	                16.Migration_Europe  3.74%
# 	                          34.Famous  3.29%
# 	              37.Military_Maneuvers  2.82%
# 	                      20.Explosions  1.45%
# 	          07.Crisis_Syrian conflict  1.07%
#
# Document 6701 Tagged for: 06.Crisis_Ukrainian
# Predictions (with probability of more than one percent):
# 	                06.Crisis_Ukrainian  64.15%
# 	                         24.Rockets  29.27%
# 	  03.Weapons_and_military_equipment  22.71%
# 	              37.Military_Maneuvers  14.11%
#
# Document 6801 Tagged for: 07.Crisis_Syrian conflict , 03.Weapons_and_military_equipment
# Predictions (with probability of more than one percent):
# 	  03.Weapons_and_military_equipment  79.45%
# 	              37.Military_Maneuvers  28.42%
# 	                         24.Rockets  17.92%
# 	          07.Crisis_Syrian conflict  5.48%
# 	                   25.Army_Aircraft  1.70%
# 	                    22.Groups_armed  1.61%
#
# Document 6901 Tagged for: 25.Army_Aircraft
# Predictions (with probability of more than one percent):
# 	                   25.Army_Aircraft  91.30%
# 	  03.Weapons_and_military_equipment  33.35%
# 	          13.Technology_Information  1.24%
#
# Document 7001 Tagged for: 39.Economy_Indicators
# Predictions (with probability of more than one percent):
# 	              39.Economy_Indicators  99.12%
# 	                  12.StockExchanges  13.52%
#
# Document 7101 Tagged for: 07.Crisis_Syrian conflict , 24.Rockets
# Predictions (with probability of more than one percent):
# 	  03.Weapons_and_military_equipment  39.85%
# 	                         24.Rockets  17.04%
# 	          07.Crisis_Syrian conflict  8.25%
# 	               26.Economy_Sanctions  2.41%
# 	                    22.Groups_armed  1.89%
# 	  01.Agreement_Iran_Nuclear_weapons  1.34%
#
# Document 7201 Tagged for: 34.Famous
# Predictions (with probability of more than one percent):
# 	                          34.Famous  100.00%
#
# Document 7301 Tagged for: 21.Crimes
# Predictions (with probability of more than one percent):
# 	                          21.Crimes  80.52%
# 	                10.Election_America  8.03%
# 	                          34.Famous  2.48%
#
# Document 7401 Tagged for: 34.Famous
# Predictions (with probability of more than one percent):
# 	                          34.Famous  99.89%
#
# Document 7501 Tagged for: 24.Rockets , 03.Weapons_and_military_equipment
# Predictions (with probability of more than one percent):
# 	                   25.Army_Aircraft  92.33%
# 	  03.Weapons_and_military_equipment  14.21%
# 	          07.Crisis_Syrian conflict  9.53%
# 	                         24.Rockets  2.12%
# 	                    22.Groups_armed  1.17%
#
# Document 7601 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  100.00%
#
# Document 7701 Tagged for: 08.Crisis_Yemenis
# Predictions (with probability of more than one percent):
# 	                  08.Crisis_Yemenis  99.27%
# 	     09.Recognition_State_Palestine  4.22%
#
# Document 7801 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  100.00%
#
# Document 7901 Tagged for: 21.Crimes , 33.Drugs
# Predictions (with probability of more than one percent):
# 	                           33.Drugs  97.88%
# 	                          21.Crimes  10.97%
#
# Document 8001 Tagged for: 04.Oil_markets
# Predictions (with probability of more than one percent):
# 	                     04.Oil_markets  100.00%
#
# Document 8101 Tagged for: 03.Weapons_and_military_equipment , 04.Oil_markets
# Predictions (with probability of more than one percent):
# 	              39.Economy_Indicators  90.77%
# 	                     04.Oil_markets  87.63%
# 	                  12.StockExchanges  2.12%
#
# Document 8201 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  90.80%
# 	                    22.Groups_armed  10.25%
# 	      15.Opposition_Syrian conflict  8.69%
# 	         28.Operation_Freeing_Mosul  2.37%
#
# Document 8301 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  100.00%
#
# Document 8401 Tagged for: 39.Economy_Indicators
# Predictions (with probability of more than one percent):
# 	              39.Economy_Indicators  80.15%
# 	                   14.Tourism_World  71.31%
# 	               26.Economy_Sanctions  7.26%
# 	                     04.Oil_markets  7.20%
# 	  03.Weapons_and_military_equipment  1.87%
# 	          13.Technology_Information  1.71%
#
# Document 8501 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  89.57%
# 	      15.Opposition_Syrian conflict  17.34%
# 	                    22.Groups_armed  4.44%
# 	                   25.Army_Aircraft  1.14%
#
# Document 8601 Tagged for: 11.Research_Medical
# Predictions (with probability of more than one percent):
# 	             36.General_information  73.17%
# 	                     05.Discoveries  38.72%
# 	                11.Research_Medical  4.61%
# 	          13.Technology_Information  1.81%
#
# Document 8701 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  100.00%
#
# Document 8801 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  100.00%

# %% [markdown]
# #### Calculate different metrics
# All metrics are calculated using the following indicator function: some label is treated as predicted, if its probability isn't less than some threshold.
# We set 50% as a value of this threshold.

# %%
rankThreshold = 0.5

def rankIndicator(labels, predictions, index):
    global rankThreshold
    return (labels[index] == 1), (predictions[index] >= rankThreshold)
    
def getPrediction(entry):
    return entry[1]

ds = datetime.datetime.now()
res = model.predict(test_arrays)
de = datetime.datetime.now()
print ("Dataset containing %d documents predicted in %s\n"%(len(test_arrays), showTime(ds, de)))

# General results   
tp = 0
fp = 0
fn = 0
qTags = 0
qPreds = 0
for i in range(len(test_labels)):
    for j in range(len(categories)):
        actual, predicted = rankIndicator(test_labels[i], res[i], j)
        if predicted:
            qPreds += 1
            if actual:
                qTags += 1
                tp += 1
            else:
                fp += 1
        else:
            if actual:
                qTags += 1
                fn += 1
print ("Labels actual: %d, predicted: %d, correctly: %d, incorrectly: %d, not predicted: %d"%(qTags, qPreds, tp, fp, fn))

#Exact Match Ratio
wrongPreds = 0
for i in range(len(test_labels)):
    for j in range(len(categories)):
        actual, predicted = rankIndicator(test_labels[i], res[i], j)
        if (actual and not predicted) or (predicted and not actual):
            wrongPreds += 1
            break;
print ("Exact Match Ratio:  %.2f%%" % ((len(test_labels) - wrongPreds)/len(test_labels) * 100))

#Accuracy
accuracy = 0.
for i in range(len(test_labels)):
    labels = sum(test_labels[i])
    tp = 0
    tfp = 0
    for j in range(len(categories)):
        actual, predicted = rankIndicator(test_labels[i], res[i], j)
        if actual and predicted:
            tp += 1
        if predicted and not actual:
            tfp += 1
    accuracy += tp / (labels + tfp)
print ("Accuracy:  %.2f%%" % (accuracy / len(test_labels) * 100))  

#Precision
precision = 0.
for i in range(len(test_labels)):
    labels = sum(test_labels[i])
    tp = 0
    tfp = 0
    for j in range(len(categories)):
        actual, predicted = rankIndicator(test_labels[i], res[i], j)
        if actual and predicted:
            tp += 1
    precision += tp / labels
print ("Precision:  %.2f%%" % (precision / len(test_labels) * 100))  

#Recall
recall = 0.
for i in range(len(test_labels)):
    labels = sum(test_labels[i])
    tp = 0
    tfp = 0
    for j in range(len(categories)):
        actual, predicted = rankIndicator(test_labels[i], res[i], j)
        if actual and predicted:
            tp += 1
        if predicted:
            tfp += 1
    if tfp > 0:
        recall += tp / tfp
print ("Recall:  %.2f%%" % (recall / len(test_labels) * 100))  

#F1-Measure
f1 = 0.
for i in range(len(test_labels)):
    labels = sum(test_labels[i])
    tp = 0
    tfp = 0
    for j in range(len(categories)):
        actual, predicted = rankIndicator(test_labels[i], res[i], j)
        if actual and predicted:
            tp += 1
        if predicted:
            tfp += 1
    f1 += 2 * tp / (tfp + labels)
print ("F1-Measure:  %.2f%%" % (f1 / len(test_labels) * 100))

#Hamming Loss
hl = 0.
for i in range(len(test_labels)):
    labels = sum(test_labels[i])
    for j in range(len(categories)):
        actual, predicted = rankIndicator(test_labels[i], res[i], j)
        if (actual and not predicted) or (predicted and not actual):
            hl += 1
print ("Hamming Loss:  %.2f%%" % (hl * 100 / (len(test_labels) * len(categories)))) 

#Macro-Averaged Precision
precision = 0
for i in range(len(categories)):
    tp = 0
    tact = 0
    for j in range(len(test_labels)):
        actual, predicted = rankIndicator(test_labels[j], res[j], i) 
        if not actual:
            continue
        tact += 1
        if predicted:
            tp += 1
    precision += tp / tact
print ("Macro-Averaged Precision:  %.2f%%" % (precision / len(categories) * 100))  

#Macro-Averaged Recall
recall = 0
for i in range(len(categories)):
    tp = 0
    tact = 0
    for j in range(len(test_labels)):
        actual, predicted = rankIndicator(test_labels[j], res[j], i)
        if predicted:
            tact += 1
            if actual:
                tp += 1
    recall += tp / tact
print ("Macro-Averaged Recall:  %.2f%%" % (recall / len(categories) * 100))  

#Macro-Averaged F1-Measure
f1 = 0
for i in range(len(categories)):
    tp = 0
    tact = 0
    labs = 0
    for j in range(len(test_labels)):
        actual, predicted = rankIndicator(test_labels[j], res[j], i)
        if actual:
            labs += 1
        if predicted:
            tact += 1
            if actual:
                tp += 1
    f1 += 2 * tp / (tact + labs)
print ("Macro-Averaged F1-Measure:  %.2f%%" % (f1 / len(categories) * 100))  

#Micro-Averaged Precision
precision = 0
tp = 0
tact = 0
for i in range(len(categories)):
    for j in range(len(test_labels)):
        actual, predicted = rankIndicator(test_labels[j], res[j], i) 
        if not actual:
            continue
        tact += 1
        if predicted:
            tp += 1
precision += tp / tact
print ("Micro-Averaged Precision:  %.2f%%" % (precision * 100))  

#Micro-Averaged Recall
recall = 0
tp = 0
tact = 0
for i in range(len(categories)):
    for j in range(len(test_labels)):
        actual, predicted = rankIndicator(test_labels[j], res[j], i)
        if predicted:
            tact += 1
            if actual:
                tp += 1
recall += tp / tact
print ("Micro-Averaged Recall:  %.2f%%" % (recall * 100))  

#Micro-Averaged F1-Measure
f1 = 0
tp = 0
tact = 0
labs = 0
for i in range(len(categories)):
    for j in range(len(test_labels)):
        actual, predicted = rankIndicator(test_labels[j], res[j], i)
        if actual:
            labs += 1
        if predicted:
            tact += 1
            if actual:
                tp += 1
f1 += 2 * tp / (tact + labs)
print ("Micro-Averaged F1-Measure:  %.2f%%" % (f1 * 100))  

#One error
o_err = 0
for i in range(len(test_labels)):
    list = [(0,0) for i in range(len(categories))]
    for j in range(len(categories)):
        list[j] = (test_labels[i][j], res[i][j])
    list.sort(key=getPrediction, reverse=True)
    if list[0][0] == 0:
        o_err += 1
print ("One Error: %.2f%%" % (o_err / len(test_labels) * 100))

#Coverage
stepsDown = 0
for i in range(len(test_labels)):
    bound = sum(test_labels[i]) - 1
    list = [(0,0,0) for i in range(len(categories))]
    for j in range(len(categories)):
        list[j] = (test_labels[i][j], res[i][j], j)
    list.sort(key=getPrediction, reverse=True)
    eSteps = 0
    for j in range(len(categories)):
        if test_labels[i][j] == 0:
            continue
        for k in range(len(list)):
            if list[k][2] == j:
                eSteps = max(eSteps, k)
    stepsDown += max(0, eSteps - bound)
print ("Coverage: %.2f" % (stepsDown / len(test_labels))) 

#Ranking Loss
rl = 0
for i in range(len(test_labels)):
    mult = sum(test_labels[i])
    list = [(0,0) for i in range(len(categories))]
    wrongOrder = 0
    for j in range(len(categories)):
        list[j] = (test_labels[i][j], res[i][j])
    list.sort(key=getPrediction, reverse=True)
    for j in range(len(list)):
        if list[j][0] == 1:
            mult -= 1
            if mult == 0:
                break
            continue
        wrongOrder += mult
    rl += wrongOrder / sum(test_labels[i])
print ("Ranking Loss: %.2f" % (rl / len(test_labels)))
# Out:
# Dataset containing 8836 documents predicted in less than 1 sec
#
# Labels actual: 11060, predicted: 9488, correctly: 7604, incorrectly: 1884, not predicted: 3456
# Exact Match Ratio:  60.80%
# Accuracy:  71.03%
# Precision:  74.38%
# Recall:  78.23%
# F1-Measure:  74.57%
# Hamming Loss:  1.51%
# Macro-Averaged Precision:  65.85%
# Macro-Averaged Recall:  76.81%
# Macro-Averaged F1-Measure:  70.15%
# Micro-Averaged Precision:  68.75%
# Micro-Averaged Recall:  80.14%
# Micro-Averaged F1-Measure:  74.01%
# One Error: 19.07%
# Coverage: 0.73
# Ranking Loss: 0.58
