# %% [markdown]
# #### Declarations and definitions

# %%
import numpy
import gensim
from gensim.models.word2vec import Word2Vec
from keras.preprocessing import sequence
from gensim.models.doc2vec import TaggedDocument
from collections import namedtuple
from keras.models import load_model
import statistics
import random
import glob
import os
import datetime
from pathlib import Path
import matplotlib.pyplot as plt

homePath = str(Path.home()) + "/MLClassificationData"
LabeledSentence = gensim.models.doc2vec.TaggedDocument
# Dimension of word vectors
n_dim = 100
# Count of categories (labels).
n_cats = 0
# Count of words, which aren't found in w2v vocabulary.
nf_words = 0
# This id is included into the names of models, created by this notebook.
modelId = 1
# Path to tokenized corpus for training
trainRoot = homePath + '/train/rtanews/target'
# Path to tokenized corpus for testing
testRoot = homePath + '/test/rtanews/target'
# Path for saving best results, achieved in the time of training
best_models_path = homePath + '/models/rtanews/tempModels/'
# Path for full model info
modelInfoPath = homePath + '/models/rtanews/modelinfo/'
# Part of the training corpus, used for runtime validation
valPart = 0.15
batch_size = 128
numpy.random.seed(1)
cnt = 0
nCats = 0
categories = dict()

LabeledDocument = namedtuple('LabeledDocument', 'words labels qLabs name')

def getCategories(path):
    cats = dict()
    nCats = 0
    os.chdir(path)
    for f in glob.glob("*"):
        if os.path.isdir(f):
            cats[f] = nCats
            nCats += 1
    return cats

def prepareDocsData(path, cats):
    files = dict()
    fInCats = [0] * len(cats)
    nFiles = 0
    actFiles = 0
    curCategory = 0
    docs = []
    os.chdir(path)
    rootDir = os.getcwd()
    for f in glob.glob("*"):
        curCategory = cats[f]
        catPath = path + "/" + f
        os.chdir(catPath)
        for fc in glob.glob("*"):
            actFiles += 1
            if fc not in files:
                nFiles += 1
                fPath = catPath + "/" + fc
                docCont = ''
                with open(fc, 'r', encoding='UTF-8') as tc:
                    for line in tc:
                        docCont += line.strip() + " "
                tc.close()
                words = docCont.strip().split() 
                labels = [0] * len(cats)
                labels[curCategory] = 1
                files[fc] = LabeledDocument(words, labels, [1], fc)
            else:
                files[fc].labels[curCategory] = 1
                files[fc].qLabs[0] += 1
            fInCats[curCategory] += 1
    for k, val in files.items():
        docs.append(val)
    return docs, fInCats

def getLabelSets(docs):
    labels = [x[1] for x in docs]
    results = [labels[0]]
    qLabs = 0
    for i in range(len(labels)):        
        if i%1000 == 0:
            print (str(i), end='\r')
        qLabs += sum(labels[i])
        count = 0
        for j in range(len(results)):
            for k in range(len(categories)):
                if labels[i][k] != results[j][k]:
                    count += 1
                    break
        if count == len(results):
            results.append(labels[i])
    return len(results), qLabs
    
def showTime(ds,de):
    result = ''
    seconds = (de-ds).total_seconds()
    if seconds < 1:
        return "less than 1 sec"
    hh = int(seconds/(60*60));
    if hh > 0:
        result = "%d h:"%(hh);
    seconds -= hh*60*60
    mm = int(seconds/60);
    if mm > 0:
        result += "%d min:"%(mm)
    ss = seconds - mm*60;
    result += "%d sec"%(ss)
    return result

def showDocsByLength(plt):
    fig, (plot1, plot2) = plt.subplots(1, 2, figsize=(10,6))    
    dictLens = dict()
    dictLens1 = dict()
    for i in range(len(trainDocs)):
        lend = "%5d"%(len(trainDocs[i].words))
        if not lend in dictLens:
            dictLens[lend] = 1
        else:
            dictLens[lend] += 1
    lens = sorted(list(dictLens.items()))
    lvars = [int(x[0]) for x in lens]
    locc = [x[1] for x in lens]
    plot1.set_title ("Documents by tokens in training set")
    plot1.set_ylabel("Documents")
    plot1.set_xlabel("Tokens")
    plot1.plot(lvars, locc, "b.-") 
    for i in range(len(testDocs)):
        lend = "%5d"%(len(testDocs[i].words))
        if not lend in dictLens1:
            dictLens1[lend] = 1
        else:
            dictLens1[lend] += 1
    lens1 = sorted(list(dictLens1.items()))
    lvars1 = [int(x[0]) for x in lens1]
    locc1 = [x[1] for x in lens1]
    plot2.set_title ("Documents by tokens in testing set")
    #plot2.set_ylabel("Documents")
    plot2.set_xlabel("Tokens")
    plot2.yaxis.tick_right()
    plot2.plot(lvars1, locc1, "b.-") 
    plt.show()
    
def showDocsByLabs(plt):
    fig, (plot1, plot2) = plt.subplots(1, 2, figsize=(10,6))
    dictLabs = dict()
    dictLabs1 = dict()
    for i in range(len(trainDocs)):
        lab = "%5d"%(trainDocs[i].qLabs[0])
        if not lab in dictLabs:
            dictLabs[lab] = 1
        else:
            dictLabs[lab] += 1
    labs = sorted(list(dictLabs.items()))
    lvars1 = [int(x[0]) for x in labs]
    locc1 = [x[1] for x in labs]
    plot1.set_title ("Documents by labels in training set")
    plot1.set_ylabel("Documents")
    plot1.set_xlabel("Labels")
    plot1.set_xticks(numpy.arange(0, len(categories), step=1))
    plot1.plot(lvars1, locc1, "bo-")
    for i in range(len(testDocs)):
        lab = "%5d"%(testDocs[i].qLabs[0])
        if not lab in dictLabs1:
            dictLabs1[lab] = 1
        else:
            dictLabs1[lab] += 1
    labs1 = sorted(list(dictLabs1.items()))
    lvars2 = [int(x[0]) for x in labs1]
    locc2 = [x[1] for x in labs1]
    plot2.set_title ("Documents by labels in testing set")
    #plot2.set_ylabel("Documents")
    plot2.set_xlabel("Labels")
    plot2.set_xticks(numpy.arange(0, len(categories), step=1))
    plot2.yaxis.tick_right()
    plot2.plot(lvars2, locc2, "bo-")
    plt.show()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Loading input datasets
# Load documents from the files, placed under given root folders (for training and testing separately).
# Files wich belong to some specific category are placed into the same subfolder of the root.
# Name of such subfolder is treated as a name of category.
# File which belongs to few categories should be copied into all correspondig subfolders (but will be loaded only once).

# %%
ds = datetime.datetime.now()
categories = getCategories(trainRoot)
#print (categories)
trainAllDocs, fInCats1 = prepareDocsData(trainRoot, categories)
trainAllDocs = random.sample(trainAllDocs, len(trainAllDocs))
trainDocs = trainAllDocs[:int(len(trainAllDocs) * (1 - valPart))]
valDocs = trainAllDocs[int(len(trainAllDocs) * (1 - valPart)):]
testDocs, fInCats2 = prepareDocsData(testRoot, categories)
testDocs = random.sample(testDocs, len(testDocs))
de = datetime.datetime.now()

print ("Load input data in %s"%(showTime(ds, de)))
# Out:
# Load input data in 3 sec

# %% [markdown]
# #### Dataset analysis

# %%
print ("Dataset properties:")
maxDocLen = max(len(x.words) for x in trainAllDocs)
minDocLen = min(len(x.words) for x in trainAllDocs)
avrgDocLen = round(statistics.mean(len(x.words) for x in trainAllDocs), 2)
dls, qLabs = getLabelSets(trainAllDocs)

print ('Loaded %d documents: %d for training, %d for validation, %d for test' % (len(trainAllDocs) + len(testDocs), len(trainDocs), len(valDocs), len(testDocs)))
print ("Tokens in documents: maximum: %d, minimum: %d, average: %d"%(maxDocLen, minDocLen, avrgDocLen))
showDocsByLength(plt);
print ("Categories (labels): %d"%(len(categories)))
print ("Documents for training in category : maximum: %d, minimum: %d, avegare: %d"%(max(fInCats1), min(fInCats1), round(statistics.mean(fInCats1), 2)))
print ("Documents for testing  in category : maximum: %d, minimum: %d, avegare: %d"%(max(fInCats2), min(fInCats2), round(statistics.mean(fInCats2), 2)))
showDocsByLabs(plt)
print ("Distinct Label Set: %d"%(dls))
print ("Proportion of Distinct Label Set: %.4f"%(dls/len(trainAllDocs)))
print ("Label Cardinality: %.4f"%(qLabs/len(trainAllDocs)))
print ("Label Density: %.4f"%(qLabs/len(trainAllDocs)/len(categories)))

del trainAllDocs
# Out:
# Dataset properties:
# Loaded 23837 documents: 12750 for training, 2251 for validation, 8836 for test
# Tokens in documents: maximum: 1330, minimum: 46, average: 170
# Categories (labels): 40
# Documents for training in category : maximum: 2800, minimum: 93, avegare: 415
# Documents for testing  in category : maximum: 1501, minimum: 65, avegare: 276
# Distinct Label Set: 290
# Proportion of Distinct Label Set: 0.0193
# Label Cardinality: 1.1073
# Label Density: 0.0277

# %% [markdown]
# #### Load W2V model
# Load Word2Vec model, saved previously in a text format.

# %%
# Name of file with word vectors
modelName = 'model-2018-Nov-12-011941.vec'
#modelName = 'wiki_ar.vec'
ds = datetime.datetime.now()
w2v = gensim.models.KeyedVectors.load_word2vec_format(homePath + '/w2v/vectors/' + modelName)
de = datetime.datetime.now()
print ("Load W2V model (%s) in %s"%(modelName, showTime(ds, de))) 
print ("Continue")
# Out:
# Load W2V model (model-2018-Nov-12-011941.vec) in 1 min:38 sec
# Continue

# %% [markdown]
# #### Prepare data for training and testing
# Input data is converted into array of sequences so that documents of different length are represented by sequences of numbers of the same size.

# %%
nf_words = 0
sdict = dict()
nfw = []
def getDocsArray(tokens, wvModel, dataType):
    global n_dim
    global tmpCount
    global nf_words
    global sdict
    global nfw
    tmpCount = tmpCount + 1
    if tmpCount != 0 and tmpCount%1000 == 0:
        print(dataType + ": prepare ", tmpCount, end="\r")
        
    vec = numpy.zeros(n_dim).reshape((1, n_dim))
    count = 0.
    for word in tokens:
        if word not in sdict:
            sdict[word] = 1
        else:
            sdict[word] = sdict[word] + 1
    for word in tokens:
        try:
            vec += wvModel[word].reshape((1, n_dim)) 
            count += 1.
        except KeyError:
            if sdict[word] == 1:
                nf_words += 1
                if nf_words < 10:
                    nfw.append(word)
            continue
    if count != 0:
        vec /= count
    return vec
    
ds = datetime.datetime.now()
tmpCount = 0
train_arrays = numpy.concatenate([getDocsArray(x.words, w2v, 'Train') for x in trainDocs])
tmpCount = 0
val_arrays = numpy.concatenate([getDocsArray(x.words, w2v, 'Validation') for x in valDocs])
train_labels = numpy.concatenate([numpy.array(x.labels).reshape(1, len(categories)) for x in trainDocs])
val_labels = numpy.concatenate([numpy.array(x.labels).reshape(1, len(categories)) for x in valDocs])
tmpCount = 0
de = datetime.datetime.now()
print ("Prepare train and validation data in %s"%(showTime(ds, de)))

ds = datetime.datetime.now()
test_arrays = numpy.concatenate([getDocsArray(x.words, w2v, "Test") for x in testDocs])
test_labels = numpy.concatenate([numpy.array(x.labels).reshape(1, len(categories)) for x in testDocs])
de = datetime.datetime.now()
print ("Prepare test data in %s"%(showTime(ds, de)))
print ("Unique words in all documents: %d"%(len(sdict)))
print ("Words not found in the w2v vocabulary: %d"%(nf_words))
# Out:
# Prepare train and validation data in 33 sec
# Prepare test data in 20 sec
# Unique words in all documents: 155089
# Words not found in the w2v vocabulary: 34340

# %% [markdown]
# #### Create, train and test the model
# Classification model is created here as an linear stack of few regular densely-connected neural network's layers.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.callbacks import ModelCheckpoint
from keras import optimizers
from keras.metrics import categorical_accuracy
import math

def getModel(n_dim):
    global batch_size
    model = Sequential()
    model.add(Dense(256, activation='relu', input_dim=n_dim))
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(len(categories), activation='sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    return model    

model = getModel(n_dim)
# Quantity of epochs (loops) in which model is trained
eps = 30
verbose = 0
checkpoint = ModelCheckpoint(best_models_path + 'curModel%d.hdf5'%(modelId), monitor='val_acc', verbose=verbose, save_best_only=True, mode='auto')
print("Start training...", end='\r')

ds = datetime.datetime.now()
model.fit(train_arrays, train_labels, epochs=eps, validation_data=(val_arrays, val_labels), batch_size=batch_size, verbose=0, callbacks=[checkpoint], shuffle=False)
de = datetime.datetime.now()
print ("Model trained in %s"%(showTime(ds, de)))

# Evaluation of the final model
scores = model.evaluate(test_arrays, test_labels, verbose=1)
print("Final model accuracy: %.2f%%" % (scores[1]*100))

# Evaluation of the best model, saved in the training time
model1 = load_model(best_models_path + 'curModel%d.hdf5'%(modelId))
scores = model1.evaluate(test_arrays, test_labels, verbose=1)
print("Last saved model accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Model trained in 27 sec
# 8836/8836 [==============================] - 0s 47us/step
# Final model accuracy: 98.51%
# 8836/8836 [==============================] - 1s 59us/step
# Last saved model accuracy: 98.52%

# %% [markdown]
# #### Save the model

# %%
# Set 'False' if you want to use the best model, saved in the training time
useFinalModel = True

modelPath = homePath + "/models/rtanews/models/"
modelName = "model%d-%s"%(modelId, datetime.datetime.now().strftime("%Y-%b-%d-%H%M%S"))

ds = datetime.datetime.now() 
if not useFinalModel:
    del model
    model = model1    
model.save(modelPath + modelName)
os.remove(best_models_path + 'curModel%d.hdf5'%(modelId))
de = datetime.datetime.now()
print ("Model %s saved in %s"%(modelName, showTime(ds,de)))
# Out:
# Model model1-2019-Jan-09-215811 saved in less than 1 sec

# %% [markdown]
# #### Check results visually

# %%
cNames = [''] * len(categories)
step = 100

def getPrediction(entry):
    return entry[1]

for k,v in categories.items():
    cNames[v] = k
for id in range(0, len(test_arrays)-1, step):
    if id > 0:
        print()
    taggedFor = "Tagged for: "
    cTags = 0
    for i in range(len(categories)):
        if test_labels[id][i] == 1:
            if cTags != 0:
                taggedFor += " , "
            cTags += 1        
            taggedFor += cNames[i]        
    res = model.predict(test_arrays[id].reshape(1, n_dim))
    list = [(0,0) for i in range(len(categories))]
    for i in range(len(categories)):
        list[i] = (i, res[0][i])
    list.sort(key=getPrediction, reverse=True)
    print ("Document %d %s"%(id+1, taggedFor))
    print ("Predictions (with probability of more than one percent):")
    for i in range(len(categories)):
        if list[i][1] >= 0.01:
            print ("\t%35s  %.2f%%" % (cNames[list[i][0]], list[i][1] * 100))
# Out:
# Document 1 Tagged for: 23.Sports_Other
# Predictions (with probability of more than one percent):
# 	                    23.Sports_Other  99.94%
#
# Document 101 Tagged for: 37.Military_Maneuvers
# Predictions (with probability of more than one percent):
# 	              37.Military_Maneuvers  61.12%
# 	                06.Crisis_Ukrainian  48.89%
# 	  03.Weapons_and_military_equipment  12.11%
# 	                         24.Rockets  1.98%
#
# Document 201 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  99.87%
#
# Document 301 Tagged for: 08.Crisis_Yemenis , 03.Weapons_and_military_equipment
# Predictions (with probability of more than one percent):
# 	  03.Weapons_and_military_equipment  65.75%
# 	                  08.Crisis_Yemenis  38.50%
# 	                    22.Groups_armed  6.15%
# 	                           33.Drugs  5.75%
# 	                          21.Crimes  5.44%
# 	                         24.Rockets  4.21%
# 	              39.Economy_Indicators  3.77%
# 	                     04.Oil_markets  3.69%
# 	  01.Agreement_Iran_Nuclear_weapons  2.46%
# 	               26.Economy_Sanctions  1.55%
#
# Document 401 Tagged for: 08.Crisis_Yemenis
# Predictions (with probability of more than one percent):
# 	                  08.Crisis_Yemenis  99.16%
# 	                    22.Groups_armed  3.99%
#
# Document 501 Tagged for: 25.Army_Aircraft
# Predictions (with probability of more than one percent):
# 	                   25.Army_Aircraft  81.05%
# 	                31.Catastrophes_Air  15.33%
# 	                06.Crisis_Ukrainian  2.20%
# 	          07.Crisis_Syrian conflict  2.00%
# 	                         24.Rockets  1.57%
# 	  03.Weapons_and_military_equipment  1.26%
#
# Document 601 Tagged for: 08.Crisis_Yemenis
# Predictions (with probability of more than one percent):
# 	                  08.Crisis_Yemenis  60.54%
# 	              39.Economy_Indicators  18.49%
# 	                     04.Oil_markets  5.33%
#
# Document 701 Tagged for: 38.Music
# Predictions (with probability of more than one percent):
# 	          13.Technology_Information  81.90%
# 	                     05.Discoveries  34.76%
# 	             36.General_information  7.17%
# 	                           38.Music  1.47%
#
# Document 801 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  99.94%
#
# Document 901 Tagged for: 05.Discoveries
# Predictions (with probability of more than one percent):
# 	                     05.Discoveries  96.86%
# 	                     04.Oil_markets  15.55%
#
# Document 1001 Tagged for: 21.Crimes
# Predictions (with probability of more than one percent):
# 	                          21.Crimes  67.55%
# 	                          34.Famous  7.29%
# 	                    22.Groups_armed  3.46%
# 	          07.Crisis_Syrian conflict  3.17%
# 	                        32.Refugees  1.66%
# 	                     18.Coup_Turkey  1.52%
# 	                      20.Explosions  1.24%
#
# Document 1101 Tagged for: 24.Rockets
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  36.02%
# 	                06.Crisis_Ukrainian  35.10%
# 	              37.Military_Maneuvers  15.09%
# 	                16.Migration_Europe  7.49%
# 	  03.Weapons_and_military_equipment  5.96%
# 	                        32.Refugees  1.86%
#
# Document 1201 Tagged for: 22.Groups_armed , 03.Weapons_and_military_equipment
# Predictions (with probability of more than one percent):
# 	                         24.Rockets  42.65%
# 	                   25.Army_Aircraft  3.33%
# 	  01.Agreement_Iran_Nuclear_weapons  3.10%
# 	  03.Weapons_and_military_equipment  1.24%
#
# Document 1301 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  100.00%
#
# Document 1401 Tagged for: 07.Crisis_Syrian conflict , 32.Refugees
# Predictions (with probability of more than one percent):
# 	                        32.Refugees  93.05%
# 	          07.Crisis_Syrian conflict  66.39%
# 	                16.Migration_Europe  9.32%
# 	     09.Recognition_State_Palestine  3.04%
# 	                    22.Groups_armed  1.79%
#
# Document 1501 Tagged for: 07.Crisis_Syrian conflict , 15.Opposition_Syrian conflict , 22.Groups_armed
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  63.35%
# 	                    22.Groups_armed  36.81%
# 	      15.Opposition_Syrian conflict  16.07%
# 	                        32.Refugees  2.48%
# 	         28.Operation_Freeing_Mosul  2.45%
# 	  03.Weapons_and_military_equipment  2.27%
# 	                    40.Attacs_Paris  1.54%
#
# Document 1601 Tagged for: 32.Refugees
# Predictions (with probability of more than one percent):
# 	                16.Migration_Europe  91.76%
# 	                        32.Refugees  41.89%
# 	          07.Crisis_Syrian conflict  7.19%
#
# Document 1701 Tagged for: 34.Famous
# Predictions (with probability of more than one percent):
# 	                          34.Famous  99.99%
#
# Document 1801 Tagged for: 02.Referendum_Britain
# Predictions (with probability of more than one percent):
# 	              02.Referendum_Britain  93.45%
# 	                16.Migration_Europe  10.67%
# 	                        32.Refugees  3.15%
# 	              39.Economy_Indicators  2.45%
#
# Document 1901 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  99.98%
#
# Document 2001 Tagged for: 13.Technology_Information
# Predictions (with probability of more than one percent):
# 	          13.Technology_Information  96.11%
# 	             36.General_information  13.31%
# 	                     05.Discoveries  3.84%
#
# Document 2101 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  99.91%
#
# Document 2201 Tagged for: 26.Economy_Sanctions
# Predictions (with probability of more than one percent):
# 	                     04.Oil_markets  90.09%
# 	               26.Economy_Sanctions  6.76%
# 	                   14.Tourism_World  5.49%
# 	              39.Economy_Indicators  5.38%
# 	          07.Crisis_Syrian conflict  2.18%
# 	  01.Agreement_Iran_Nuclear_weapons  1.02%
#
# Document 2301 Tagged for: 23.Sports_Other
# Predictions (with probability of more than one percent):
# 	                    23.Sports_Other  99.87%
#
# Document 2401 Tagged for: 08.Crisis_Yemenis
# Predictions (with probability of more than one percent):
# 	                  08.Crisis_Yemenis  99.77%
#
# Document 2501 Tagged for: 08.Crisis_Yemenis
# Predictions (with probability of more than one percent):
# 	                    22.Groups_armed  77.05%
# 	                  08.Crisis_Yemenis  66.85%
# 	                  35.Demonstrations  1.22%
#
# Document 2601 Tagged for: 23.Sports_Other
# Predictions (with probability of more than one percent):
# 	                    23.Sports_Other  99.83%
# 	                        30.Football  1.35%
#
# Document 2701 Tagged for: 24.Rockets
# Predictions (with probability of more than one percent):
# 	                         24.Rockets  96.22%
# 	                           29.Space  56.56%
# 	          13.Technology_Information  2.89%
#
# Document 2801 Tagged for: 32.Refugees
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  91.50%
# 	      15.Opposition_Syrian conflict  3.86%
# 	                  08.Crisis_Yemenis  3.40%
# 	                    22.Groups_armed  3.02%
# 	                        32.Refugees  2.15%
# 	               26.Economy_Sanctions  1.54%
# 	                06.Crisis_Ukrainian  1.31%
#
# Document 2901 Tagged for: 29.Space
# Predictions (with probability of more than one percent):
# 	                           29.Space  99.80%
# 	                     05.Discoveries  6.13%
#
# Document 3001 Tagged for: 20.Explosions , 22.Groups_armed
# Predictions (with probability of more than one percent):
# 	                      20.Explosions  91.93%
# 	                    22.Groups_armed  11.19%
#
# Document 3101 Tagged for: 08.Crisis_Yemenis
# Predictions (with probability of more than one percent):
# 	                  08.Crisis_Yemenis  99.90%
#
# Document 3201 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  92.13%
# 	      15.Opposition_Syrian conflict  6.15%
# 	                06.Crisis_Ukrainian  5.94%
# 	                16.Migration_Europe  2.18%
# 	                        32.Refugees  1.59%
# 	                    22.Groups_armed  1.52%
#
# Document 3301 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  98.84%
# 	      15.Opposition_Syrian conflict  3.13%
#
# Document 3401 Tagged for: 29.Space
# Predictions (with probability of more than one percent):
# 	                           29.Space  99.99%
#
# Document 3501 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  99.60%
# 	                    23.Sports_Other  1.99%
# 	      19.Olympics_Ryu_d_Janero_2016  1.46%
#
# Document 3601 Tagged for: 10.Election_America
# Predictions (with probability of more than one percent):
# 	                10.Election_America  100.00%
#
# Document 3701 Tagged for: 04.Oil_markets
# Predictions (with probability of more than one percent):
# 	                     04.Oil_markets  99.44%
#
# Document 3801 Tagged for: 33.Drugs
# Predictions (with probability of more than one percent):
# 	                           33.Drugs  99.99%
# 	                          21.Crimes  5.23%
#
# Document 3901 Tagged for: 22.Groups_armed
# Predictions (with probability of more than one percent):
# 	                    22.Groups_armed  90.95%
# 	                           33.Drugs  3.04%
# 	                   25.Army_Aircraft  1.91%
# 	                16.Migration_Europe  1.79%
# 	                      20.Explosions  1.70%
# 	                        32.Refugees  1.17%
#
# Document 4001 Tagged for: 36.General_information
# Predictions (with probability of more than one percent):
# 	             36.General_information  82.13%
# 	                     05.Discoveries  17.93%
# 	                11.Research_Medical  10.59%
# 	                        17.Diseases  3.92%
# 	                    23.Sports_Other  2.09%
# 	                           29.Space  1.29%
#
# Document 4101 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  99.99%
#
# Document 4201 Tagged for: 13.Technology_Information , 25.Army_Aircraft
# Predictions (with probability of more than one percent):
# 	          13.Technology_Information  86.86%
# 	                     05.Discoveries  55.86%
# Document 4301 Tagged for: 35.Demonstrations
# Predictions (with probability of more than one percent):
# 	                  35.Demonstrations  99.78%
# 	      19.Olympics_Ryu_d_Janero_2016  1.40%
#
# Document 4401 Tagged for: 11.Research_Medical , 33.Drugs
# Predictions (with probability of more than one percent):
# 	                11.Research_Medical  81.61%
# 	                           33.Drugs  30.40%
# 	             36.General_information  5.29%
# 	                        17.Diseases  1.78%
#
# Document 4501 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  98.63%
# 	      15.Opposition_Syrian conflict  1.29%
#
# Document 4601 Tagged for: 21.Crimes
# Predictions (with probability of more than one percent):
# 	                          21.Crimes  17.62%
# 	                           33.Drugs  7.70%
# 	             36.General_information  4.81%
# 	                           38.Music  3.12%
# 	                          34.Famous  2.83%
# 	                   14.Tourism_World  1.30%
#
# Document 4701 Tagged for: 34.Famous , 38.Music
# Predictions (with probability of more than one percent):
# 	                          34.Famous  99.99%
#
# Document 4801 Tagged for: 32.Refugees
# Predictions (with probability of more than one percent):
# 	         28.Operation_Freeing_Mosul  96.93%
# 	                    22.Groups_armed  15.72%
# 	          07.Crisis_Syrian conflict  2.15%
#
# Document 4901 Tagged for: 13.Technology_Information
# Predictions (with probability of more than one percent):
# 	          13.Technology_Information  98.92%
# 	             36.General_information  4.55%
#
# Document 5001 Tagged for: 05.Discoveries
# Predictions (with probability of more than one percent):
# 	          13.Technology_Information  87.41%
# 	                     05.Discoveries  64.78%
# 	             36.General_information  4.19%
#
# Document 5101 Tagged for: 36.General_information
# Predictions (with probability of more than one percent):
# 	          13.Technology_Information  63.19%
# 	             36.General_information  16.30%
# 	                          21.Crimes  1.72%
# 	                     05.Discoveries  1.72%
# 	                          34.Famous  1.14%
#
# Document 5201 Tagged for: 08.Crisis_Yemenis
# Predictions (with probability of more than one percent):
# 	                  08.Crisis_Yemenis  97.53%
# 	                      20.Explosions  4.50%
# 	                31.Catastrophes_Air  4.27%
# 	                    22.Groups_armed  1.70%
#
# Document 5301 Tagged for: 19.Olympics_Ryu_d_Janero_2016 , 23.Sports_Other
# Predictions (with probability of more than one percent):
# 	                    23.Sports_Other  96.20%
# 	      19.Olympics_Ryu_d_Janero_2016  35.22%
#
# Document 5401 Tagged for: 22.Groups_armed
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  63.74%
# 	                        32.Refugees  37.57%
# 	      15.Opposition_Syrian conflict  19.48%
# 	                    22.Groups_armed  11.49%
# 	                16.Migration_Europe  6.09%
# 	                     18.Coup_Turkey  2.57%
# 	                          21.Crimes  1.35%
#
# Document 5501 Tagged for: 08.Crisis_Yemenis , 20.Explosions
# Predictions (with probability of more than one percent):
# 	                  08.Crisis_Yemenis  57.40%
# 	                    22.Groups_armed  39.78%
# 	                      20.Explosions  14.18%
#
# Document 5601 Tagged for: 07.Crisis_Syrian conflict , 15.Opposition_Syrian conflict
# Predictions (with probability of more than one percent):
# 	      15.Opposition_Syrian conflict  66.37%
# 	          07.Crisis_Syrian conflict  62.47%
# 	                    22.Groups_armed  12.64%
#
# Document 5701 Tagged for: 23.Sports_Other
# Predictions (with probability of more than one percent):
# 	                    23.Sports_Other  99.98%
#
# Document 5801 Tagged for: 16.Migration_Europe , 32.Refugees
# Predictions (with probability of more than one percent):
# 	                        32.Refugees  99.92%
# 	                16.Migration_Europe  75.46%
#
# Document 5901 Tagged for: 35.Demonstrations
# Predictions (with probability of more than one percent):
# 	                  35.Demonstrations  35.00%
# 	                    22.Groups_armed  34.44%
# 	                     04.Oil_markets  10.51%
# 	                           33.Drugs  6.79%
# 	                        32.Refugees  4.04%
# 	                16.Migration_Europe  2.82%
# 	                      20.Explosions  2.81%
# 	                        30.Football  2.36%
# 	      15.Opposition_Syrian conflict  2.28%
# 	                          21.Crimes  2.22%
# 	               26.Economy_Sanctions  1.87%
# 	                  08.Crisis_Yemenis  1.51%
# 	                     18.Coup_Turkey  1.44%
# 	                   14.Tourism_World  1.28%
# 	              02.Referendum_Britain  1.19%
# 	                    40.Attacs_Paris  1.09%
# 	                        17.Diseases  1.03%
# 	              39.Economy_Indicators  1.03%
#
# Document 6001 Tagged for: 33.Drugs
# Predictions (with probability of more than one percent):
# 	                          21.Crimes  95.65%
# 	                           33.Drugs  69.75%
#
# Document 6101 Tagged for: 23.Sports_Other
# Predictions (with probability of more than one percent):
# 	                    23.Sports_Other  93.45%
# 	      19.Olympics_Ryu_d_Janero_2016  41.15%
#
# Document 6201 Tagged for: 14.Tourism_World
# Predictions (with probability of more than one percent):
# 	                   14.Tourism_World  99.93%
# 	                16.Migration_Europe  7.85%
#
# Document 6301 Tagged for: 29.Space
# Predictions (with probability of more than one percent):
# 	                           29.Space  97.18%
# 	                     05.Discoveries  19.50%
# 	             36.General_information  2.49%
#
# Document 6401 Tagged for: 03.Weapons_and_military_equipment
# Predictions (with probability of more than one percent):
# 	                   25.Army_Aircraft  73.47%
# 	  03.Weapons_and_military_equipment  15.20%
# 	                         24.Rockets  14.58%
# 	          07.Crisis_Syrian conflict  9.25%
#
# Document 6501 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  100.00%
#
# Document 6601 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  100.00%
#
# Document 6701 Tagged for: 34.Famous , 38.Music
# Predictions (with probability of more than one percent):
# 	                          34.Famous  99.90%
# 	                           38.Music  2.69%
#
# Document 6801 Tagged for: 24.Rockets , 03.Weapons_and_military_equipment
# Predictions (with probability of more than one percent):
# 	               26.Economy_Sanctions  48.20%
# 	  03.Weapons_and_military_equipment  21.30%
# 	          07.Crisis_Syrian conflict  16.19%
# 	                         24.Rockets  10.56%
# 	                   25.Army_Aircraft  3.55%
# 	  01.Agreement_Iran_Nuclear_weapons  2.52%
#
# Document 6901 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  70.80%
# 	                    22.Groups_armed  44.92%
# 	      15.Opposition_Syrian conflict  12.76%
# 	                      20.Explosions  9.34%
# 	                        32.Refugees  4.44%
# 	         28.Operation_Freeing_Mosul  1.42%
#
# Document 7001 Tagged for: 24.Rockets
# Predictions (with probability of more than one percent):
# 	                         24.Rockets  97.15%
# 	                           29.Space  37.81%
#
# Document 7101 Tagged for: 20.Explosions , 22.Groups_armed
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  63.40%
# 	                    22.Groups_armed  31.39%
# 	         28.Operation_Freeing_Mosul  8.94%
# 	      15.Opposition_Syrian conflict  6.56%
# 	  03.Weapons_and_military_equipment  3.62%
# 	                        32.Refugees  1.65%
# 	                   25.Army_Aircraft  1.51%
#
# Document 7201 Tagged for: 07.Crisis_Syrian conflict , 22.Groups_armed
# Predictions (with probability of more than one percent):
# 	                    22.Groups_armed  32.87%
# 	                    40.Attacs_Paris  28.42%
# 	          07.Crisis_Syrian conflict  13.25%
# 	         28.Operation_Freeing_Mosul  8.17%
# 	      15.Opposition_Syrian conflict  4.96%
# 	                      20.Explosions  1.68%
# 	                        32.Refugees  1.10%
#
# Document 7301 Tagged for: 23.Sports_Other
# Predictions (with probability of more than one percent):
# 	                    23.Sports_Other  99.99%
#
# Document 7401 Tagged for: 02.Referendum_Britain
# Predictions (with probability of more than one percent):
# 	              02.Referendum_Britain  99.99%
#
# Document 7501 Tagged for: 07.Crisis_Syrian conflict
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  90.99%
# 	      15.Opposition_Syrian conflict  22.66%
# 	  03.Weapons_and_military_equipment  4.01%
# 	                   25.Army_Aircraft  3.17%
# 	                    22.Groups_armed  1.72%
# 	                06.Crisis_Ukrainian  1.06%
#
# Document 7601 Tagged for: 22.Groups_armed
# Predictions (with probability of more than one percent):
# 	                    22.Groups_armed  95.24%
# 	  03.Weapons_and_military_equipment  1.89%
#
# Document 7701 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  100.00%
#
# Document 7801 Tagged for: 10.Election_America
# Predictions (with probability of more than one percent):
# 	                10.Election_America  60.03%
# 	                   25.Army_Aircraft  32.53%
# 	  03.Weapons_and_military_equipment  6.20%
# 	                06.Crisis_Ukrainian  4.72%
# 	                    22.Groups_armed  3.19%
# 	                         24.Rockets  1.76%
# 	          07.Crisis_Syrian conflict  1.47%
#
# Document 7901 Tagged for: 22.Groups_armed , 32.Refugees
# Predictions (with probability of more than one percent):
# 	                    40.Attacs_Paris  50.06%
# 	                    22.Groups_armed  45.15%
# 	                      20.Explosions  18.07%
# 	                        32.Refugees  9.07%
# 	          07.Crisis_Syrian conflict  6.17%
# 	                16.Migration_Europe  1.47%
#
# Document 8001 Tagged for: 05.Discoveries
# Predictions (with probability of more than one percent):
# 	          13.Technology_Information  88.81%
# 	                     05.Discoveries  15.69%
# 	             36.General_information  13.75%
#
# Document 8101 Tagged for: 29.Space
# Predictions (with probability of more than one percent):
# 	                           29.Space  99.79%
# 	                     05.Discoveries  7.32%
#
# Document 8201 Tagged for: 30.Football
# Predictions (with probability of more than one percent):
# 	                        30.Football  99.99%
#
# Document 8301 Tagged for: 24.Rockets , 03.Weapons_and_military_equipment
# Predictions (with probability of more than one percent):
# 	                         24.Rockets  76.65%
# 	  03.Weapons_and_military_equipment  14.09%
# 	                     05.Discoveries  8.51%
# 	          13.Technology_Information  8.15%
# 	                           29.Space  7.61%
# 	                   25.Army_Aircraft  4.67%
# 	  01.Agreement_Iran_Nuclear_weapons  1.01%
#
# Document 8401 Tagged for: 07.Crisis_Syrian conflict , 15.Opposition_Syrian conflict
# Predictions (with probability of more than one percent):
# 	      15.Opposition_Syrian conflict  62.16%
# 	          07.Crisis_Syrian conflict  45.59%
# 	                    22.Groups_armed  31.36%
# 	                        32.Refugees  5.88%
# 	                      20.Explosions  3.73%
# 	                  35.Demonstrations  2.71%
# 	                    40.Attacs_Paris  1.69%
#
# Document 8501 Tagged for: 23.Sports_Other
# Predictions (with probability of more than one percent):
# 	                        30.Football  93.28%
# 	                    23.Sports_Other  55.73%
#
# Document 8601 Tagged for: 22.Groups_armed , 24.Rockets
# Predictions (with probability of more than one percent):
# 	          07.Crisis_Syrian conflict  61.69%
# 	      15.Opposition_Syrian conflict  38.04%
# 	                    22.Groups_armed  21.78%
# 	                         24.Rockets  10.52%
# 	                   25.Army_Aircraft  6.65%
# 	  03.Weapons_and_military_equipment  6.24%
#
# Document 8701 Tagged for: 07.Crisis_Syrian conflict , 34.Famous
# Predictions (with probability of more than one percent):
# 	          13.Technology_Information  75.75%
# 	                          34.Famous  31.90%
# 	                     05.Discoveries  2.92%
# 	                           38.Music  1.15%
#
# Document 8801 Tagged for: 31.Catastrophes_Air
# Predictions (with probability of more than one percent):
# 	                31.Catastrophes_Air  99.51%

# %% [markdown]
# #### Calculate different metrics
# All metrics are calculated using the following indicator function: some label is treated as predicted, if its probability isn't less than some threshold.
# We set 50% as a value of this threshold.

# %%
rankThreshold = 0.5

def rankIndicator(labels, predictions, index):
    global rankThreshold
    return (labels[index] == 1), (predictions[index] >= rankThreshold)
    
def getPrediction(entry):
    return entry[1]

ds = datetime.datetime.now()
res = model.predict(test_arrays)
de = datetime.datetime.now()
print ("Dataset containing %d documents predicted in %s\n"%(len(test_arrays), showTime(ds, de)))

# General results   
tp = 0
fp = 0
fn = 0
qTags = 0
qPreds = 0
for i in range(len(test_labels)):
    for j in range(len(categories)):
        actual, predicted = rankIndicator(test_labels[i], res[i], j)
        if predicted:
            qPreds += 1
            if actual:
                qTags += 1
                tp += 1
            else:
                fp += 1
        else:
            if actual:
                qTags += 1
                fn += 1
print ("Labels actual: %d, predicted: %d, correctly: %d, incorrectly: %d, not predicted: %d"%(qTags, qPreds, tp, fp, fn))

#Exact Match Ratio
wrongPreds = 0
for i in range(len(test_labels)):
    for j in range(len(categories)):
        actual, predicted = rankIndicator(test_labels[i], res[i], j)
        if (actual and not predicted) or (predicted and not actual):
            wrongPreds += 1
            break;
emr = (len(test_labels) - wrongPreds)/len(test_labels)           
print ("Exact Match Ratio:  %.2f%%" % ((len(test_labels) - wrongPreds)/len(test_labels) * 100))

#Accuracy
accuracy = 0.
for i in range(len(test_labels)):
    labels = sum(test_labels[i])
    tp = 0
    tfp = 0
    for j in range(len(categories)):
        actual, predicted = rankIndicator(test_labels[i], res[i], j)
        if actual and predicted:
            tp += 1
        if predicted and not actual:
            tfp += 1
    accuracy += tp / (labels + tfp)
modelAccuracy = accuracy / len(test_labels)
print ("Accuracy:  %.2f%%" % (accuracy / len(test_labels) * 100))  

#Precision
precision = 0.
for i in range(len(test_labels)):
    labels = sum(test_labels[i])
    tp = 0
    tfp = 0
    for j in range(len(categories)):
        actual, predicted = rankIndicator(test_labels[i], res[i], j)
        if actual and predicted:
            tp += 1
    precision += tp / labels
modelPrecision = precision / len(test_labels)
print ("Precision:  %.2f%%" % (precision / len(test_labels) * 100))  

#Recall
recall = 0.
for i in range(len(test_labels)):
    labels = sum(test_labels[i])
    tp = 0
    tfp = 0
    for j in range(len(categories)):
        actual, predicted = rankIndicator(test_labels[i], res[i], j)
        if actual and predicted:
            tp += 1
        if predicted:
            tfp += 1
    if tfp > 0:
        recall += tp / tfp
modelRecall = recall / len(test_labels)      
print ("Recall:  %.2f%%" % (recall / len(test_labels) * 100))  

#F1-Measure
f1 = 0.
for i in range(len(test_labels)):
    labels = sum(test_labels[i])
    tp = 0
    tfp = 0
    for j in range(len(categories)):
        actual, predicted = rankIndicator(test_labels[i], res[i], j)
        if actual and predicted:
            tp += 1
        if predicted:
            tfp += 1
    f1 += 2 * tp / (tfp + labels)
modelF1 = f1 / len(test_labels) 
print ("F1-Measure:  %.2f%%" % (f1 / len(test_labels) * 100))

#Hamming Loss
hl = 0.
for i in range(len(test_labels)):
    labels = sum(test_labels[i])
    for j in range(len(categories)):
        actual, predicted = rankIndicator(test_labels[i], res[i], j)
        if (actual and not predicted) or (predicted and not actual):
            hl += 1
modelHl = hl / (len(test_labels) * len(categories))           
print ("Hamming Loss:  %.2f%%" % (hl * 100 / (len(test_labels) * len(categories)))) 

#Macro-Averaged Precision
precision = 0
for i in range(len(categories)):
    tp = 0
    tact = 0
    for j in range(len(test_labels)):
        actual, predicted = rankIndicator(test_labels[j], res[j], i) 
        if not actual:
            continue
        tact += 1
        if predicted:
            tp += 1
    precision += tp / tact
modelMacroPrecision = precision / len(categories) 
print ("Macro-Averaged Precision:  %.2f%%" % (precision / len(categories) * 100))  

#Macro-Averaged Recall
recall = 0
for i in range(len(categories)):
    tp = 0
    tact = 0
    for j in range(len(test_labels)):
        actual, predicted = rankIndicator(test_labels[j], res[j], i)
        if predicted:
            tact += 1
            if actual:
                tp += 1
    recall += tp / tact
modelMacroRecall = recall / len(categories)
print ("Macro-Averaged Recall:  %.2f%%" % (recall / len(categories) * 100))  

#Macro-Averaged F1-Measure
f1 = 0
for i in range(len(categories)):
    tp = 0
    tact = 0
    labs = 0
    for j in range(len(test_labels)):
        actual, predicted = rankIndicator(test_labels[j], res[j], i)
        if actual:
            labs += 1
        if predicted:
            tact += 1
            if actual:
                tp += 1
    f1 += 2 * tp / (tact + labs)
modelMacroF1 = f1 / len(categories)
print ("Macro-Averaged F1-Measure:  %.2f%%" % (f1 / len(categories) * 100))  

#Micro-Averaged Precision
precision = 0
tp = 0
tact = 0
for i in range(len(categories)):
    for j in range(len(test_labels)):
        actual, predicted = rankIndicator(test_labels[j], res[j], i) 
        if not actual:
            continue
        tact += 1
        if predicted:
            tp += 1
precision += tp / tact
modelMicroPrecision = precision
print ("Micro-Averaged Precision:  %.2f%%" % (precision * 100))  

#Micro-Averaged Recall
recall = 0
tp = 0
tact = 0
for i in range(len(categories)):
    for j in range(len(test_labels)):
        actual, predicted = rankIndicator(test_labels[j], res[j], i)
        if predicted:
            tact += 1
            if actual:
                tp += 1
recall += tp / tact
modelMicroRecall = recall
print ("Micro-Averaged Recall:  %.2f%%" % (recall * 100))  

#Micro-Averaged F1-Measure
f1 = 0
tp = 0
tact = 0
labs = 0
for i in range(len(categories)):
    for j in range(len(test_labels)):
        actual, predicted = rankIndicator(test_labels[j], res[j], i)
        if actual:
            labs += 1
        if predicted:
            tact += 1
            if actual:
                tp += 1
f1 += 2 * tp / (tact + labs)
modelMicroF1 = f1
print ("Micro-Averaged F1-Measure:  %.2f%%" % (f1 * 100))  

#One error
o_err = 0
for i in range(len(test_labels)):
    list = [(0,0) for i in range(len(categories))]
    for j in range(len(categories)):
        list[j] = (test_labels[i][j], res[i][j])
    list.sort(key=getPrediction, reverse=True)
    if list[0][0] == 0:
        o_err += 1
print ("One Error: %.2f%%" % (o_err / len(test_labels) * 100))

#Coverage
stepsDown = 0
for i in range(len(test_labels)):
    bound = sum(test_labels[i]) - 1
    list = [(0,0,0) for i in range(len(categories))]
    for j in range(len(categories)):
        list[j] = (test_labels[i][j], res[i][j], j)
    list.sort(key=getPrediction, reverse=True)
    eSteps = 0
    for j in range(len(categories)):
        if test_labels[i][j] == 0:
            continue
        for k in range(len(list)):
            if list[k][2] == j:
                eSteps = max(eSteps, k)
    stepsDown += max(0, eSteps - bound)
print ("Coverage: %.2f" % (stepsDown / len(test_labels))) 

#Ranking Loss
rl = 0
for i in range(len(test_labels)):
    mult = sum(test_labels[i])
    list = [(0,0) for i in range(len(categories))]
    wrongOrder = 0
    for j in range(len(categories)):
        list[j] = (test_labels[i][j], res[i][j])
    list.sort(key=getPrediction, reverse=True)
    for j in range(len(list)):
        if list[j][0] == 1:
            mult -= 1
            if mult == 0:
                break
            continue
        wrongOrder += mult
    rl += wrongOrder / sum(test_labels[i])
print ("Ranking Loss: %.2f" % (rl / len(test_labels)))
# Out:
# Dataset containing 8836 documents predicted in less than 1 sec
#
# Labels actual: 11060, predicted: 9341, correctly: 7567, incorrectly: 1774, not predicted: 3493
# Exact Match Ratio:  60.93%
# Accuracy:  70.89%
# Precision:  74.11%
# Recall:  78.02%
# F1-Measure:  74.33%
# Hamming Loss:  1.49%
# Macro-Averaged Precision:  65.98%
# Macro-Averaged Recall:  77.64%
# Macro-Averaged F1-Measure:  70.59%
# Micro-Averaged Precision:  68.42%
# Micro-Averaged Recall:  81.01%
# Micro-Averaged F1-Measure:  74.18%
# One Error: 18.52%
# Coverage: 0.70
# Ranking Loss: 0.56

# %% [markdown]
# #### Save model info

# %%
import pickle

modelInfoPath = homePath + '/models/rtanews/modelinfo/'
DocInfo = namedtuple('DocInfo', 'name actLabs predLabs dtype')
CategoryInfo = namedtuple('CategoryInfo', 'name actLabs predLabs wrongLabs notPredLabs qtyDocs qtyPredDocs precision recall f1')
ModelInfo = namedtuple('ModelInfo', 'name dataSet cats qtyDocs qtyPredDocs qtyPartDocs qtyWrongDocs actLabs predLabs wrongLabs notPredLabs emr accuracy precision recall f1 hl macroPrecision macroRecall macroF1 microPrecision microRecall microF1 catagories docs')

cNames = [''] * len(categories)
for k,v in categories.items():
    cNames[v] = k
mCorrDocs = 0
mPartDocs = 0
mWrongDocs = 0
cqTags = [0] * len(categories)
cqPreds = [0] * len(categories)
ctp = [0] * len(categories)
cfp = [0] * len(categories)
cfn = [0] * len(categories)
cDocs = [0] * len(categories)
cpDocs = [0] * len(categories)

docsInfo = []

for i in range(len(res)):
    qTags = 0
    qPreds = 0
    tp = 0
    fp = 0
    fn = 0
    dtype = 0
    actLabs = []
    predLabs = []
    for j in range(len(categories)):
        actual, predicted = rankIndicator(test_labels[i], res[i], j)
        if actual:
            cDocs[j] += 1
            actLabs.append(cNames[j])
        if predicted:
            qPreds += 1
            cqPreds[j] += 1
            predLabs.append(cNames[j])
            if actual:
                qTags += 1
                tp += 1
                cqTags[j] += 1
                ctp[j] += 1
                cpDocs[j] += 1
            else:
                fp += 1
                cfp[j] += 1
        else:
            if actual:
                qTags += 1
                fn += 1
                cqTags[j] += 1
                cfn[j] += 1
    if tp == qTags:
        if qPreds == tp:
            dtype = 2
        else:
            dtype = 3
        mCorrDocs += 1
    elif tp > 0:
        dtype = 1
        mPartDocs += 1
    else:
        mWrongDocs += 1
    docInfo = DocInfo(testDocs[i].name, actLabs, predLabs, dtype)
    docsInfo.append(docInfo)

categoriesInfo = []
for i in range(len(categories)):
    cPrec = ctp[i] / cqTags[i]
    cRec = ctp[i] / (ctp[i] + cfp[i])
    cF1 = 2 * ctp[i] / (ctp[i] + cfp[i] + cqTags[i])
    catInfo = CategoryInfo(cNames[i], cqTags[i], ctp[i], cfp[i], cfn[i], cDocs[i], cpDocs[i], cPrec, cRec, cF1)
    categoriesInfo.append(catInfo);

k = testRoot.rfind("/target")
sourceRoot = testRoot[:k] + "/source"
modelInfo = ModelInfo(modelName,sourceRoot,len(categories),len(res), mCorrDocs, mPartDocs, mWrongDocs, 
                      sum(cqTags),sum(ctp),sum(cfp),sum(cfn),emr,modelAccuracy,
                      modelPrecision,modelRecall,modelF1,modelHl,modelMacroPrecision,modelMacroRecall,
                      modelMacroF1,modelMicroPrecision,modelMicroRecall,modelMicroF1,categoriesInfo,docsInfo)
with open(modelInfoPath + modelName, 'wb') as f:
    pickle.dump(modelInfo, f)
print ("Model info saved.");
print ("Name: %s, data set: %s, documents: %d, categories: %d, actual labels: %d"%(modelInfo.name, modelInfo.dataSet, modelInfo.qtyDocs, modelInfo.cats, modelInfo.actLabs))
# Out:
# Model info saved.
# Name: model1-2019-Jan-09-215811, data set: /home/user/MLClassificationData/test/rtanews/source, documents: 8836, categories: 40, actual labels: 11060
